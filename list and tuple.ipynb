# %%
p = [34,75,23,675,345,75]

# %%
p.insert(2,'test@gmail.com')

# %%
p
# Out:
# [34, 75, 'test@gmail.com', 23, 675, 345, 75]

# %%
p.insert(-1,100)

# %%
p
# Out:
# [34, 75, 'test@gmail.com', 23, 675, 345, 100, 75]

# %%
p.insert(100,'pyspark')

# %%
p
# Out:
# [34, 75, 'test@gmail.com', 23, 675, 345, 100, 75, 'pyspark']

# %%
p.insert(3,[57,32334,675,6])

# %%
p
# Out:
# [34,
#  75,
#  'test@gmail.com',
#  [57, 32334, 675, 6],
#  23,
#  675,
#  345,
#  100,
#  75,
#  'pyspark']

# %%
print(p)
# Out:
# [34, 75, 'test@gmail.com', [57, 32334, 675, 6], 23, 675, 345, 100, 75, 'pyspark']

# %%
p[3].insert(2,'Python')

# %%
print(p)
# Out:
# [34, 75, 'test@gmail.com', [57, 32334, 'Python', 675, 6], 23, 675, 345, 100, 75, 'pyspark']

# %%
append(element):
to insert single element at the end

# %%
p = [101,42,45,634,75]

# %%
p.append(100)

# %%
p
# Out:
# [101, 42, 45, 634, 75, 100]

# %%
p.append(500)

# %%
p
# Out:
# [101, 42, 45, 634, 75, 100, 500]

# %%
q = []

# %%
q.append(100)

# %%
q
# Out:
# [100]

# %%
q.append(434)

# %%
q
# Out:
# [100, 434]

# %%
p.append([34,765,34,655])

# %%
p
# Out:
# [101, 42, 45, 634, 75, 100, 500, [34, 765, 34, 655]]

# %%
extend([group of elements])
to insert multiple elements at the end

# %%
p.extend([100,200,300,400])

# %%
p
# Out:
# [101, 42, 45, 634, 75, 100, 500, [34, 765, 34, 655], 100, 200, 300, 400]

# %%
append vs extend

append single element

append([]) : it will insert list as single element

extend - multiple elements

extend([]) : it wiil insert elements at the end

# %%
per = [101,'keshav','Pune']
dept = ['IT','Bang',53434343]

# %%
per.extend(dept)

# %%
per
# Out:
# [101, 'keshav', 'Pune', 'IT', 'Bang', 53434343]

# %%
p = [234,65,323,75,43,645,354,53]

# %%
how to delete element from list:
================================
1.remove
2.pop
3.clear

# %%
remove(element/Value)

# %%
emp = [101,'keshav','pune',54554,'IT']

# %%
emp.remove('pune')

# %%
emp
# Out:
# [101, 'keshav', 54554, 'IT']

# %%
emp
# Out:
# [101, 'keshav', 54554, 'IT']

# %%
emp.pop(2)
# Out:
# 54554

# %%
emp
# Out:
# [101, 'keshav', 'IT']

# %%
emp.clear()

# %%
emp
# Out:
# []

# %%
del vs clear

# %%
p = [34,75,34,64546]

# %%
p.clear()

# %%
p
# Out:
# []

# %%
del p

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 p
#
# NameError: name 'p' is not defined

# %%
#other operation

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 p
#
# NameError: name 'p' is not defined

# %%
emp
# Out:
# [101, 'keshav', 'pune', 54554, 'IT']

# %%
emp[2]= 'mumbai'

# %%
emp
# Out:
# [101, 'keshav', 'mumbai', 54554, 'IT']

# %%
emp[-1] = 'Sr.Data Engineer'

# %%
emp
# Out:
# [101, 'keshav', 'mumbai', 54554, 'Sr.Data Engineer']

# %%
p = [34,675,32324,65,342,5,53,43,563,46,4,53,53,653]

# %%
p.count(43)
# Out:
# 1

# %%
p.count(65)
# Out:
# 1

# %%
p.count(53)
# Out:
# 3

# %%
p = 'ASDFGHJ<GJFDFSFGH#$%^&*O^%$^#%@SDXCVBNasfdghhj2345678'

# %%
p = [34,65,23,56464]

# %%
len(p)
# Out:
# 4

# %%
p = [34, 65, 23, 56464,34,65]

# %%
p
# Out:
# [34, 65, 23, 56464, 34, 65]

# %%
p.index(23)
# Out:
# 2

# %%
p.index(34)
# Out:
# 0

# %%
p
# Out:
# [34, 65, 23, 56464, 34, 65]

# %%
p.sort(reverse=True)

# %%
p
# Out:
# [56464, 65, 65, 34, 34, 23]

# %%
p = [34,756,34,6756,45,45,'sdfdf','sdfgsdfg,']

# %%
p.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 p.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
p = ['SFDSDF','asdfgdg','ASDF','465465','456546']

# %%
p.sort()

# %%
p
# Out:
# ['456546', '465465', 'ASDF', 'SFDSDF', 'asdfgdg']

# %%
p = [34,56,34,75,34,75,434,47,4,54,54,534,534,5,]

# %%
p.reverse()

# %%
p
# Out:
# [5, 534, 534, 54, 54, 4, 47, 434, 75, 34, 75, 34, 56, 34]

# %%
tuple:
======
it is collection of elements
it is immutable type DS
it follows same indexing pattern as list
it is denoted by ()
it allows duplicate elements

# %%
p = (42,23,5324,24)

# %%
type(p)
# Out:
# tuple

# %%
cred = ('admin','admin@123')

# %%
cred
# Out:
# ('admin', 'admin@123')

# %%
cred.insert(4,343)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 cred.insert(4,343)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
p = (23,64,23,5,36,3,324,2,535,3,53,53,53,53,)

# %%
p.count(53)
# Out:
# 4

# %%
p.index(23)
# Out:
# 0

# %%
tuple:

# %%
p = 34,75,234,75,'python'

# %%
p
# Out:
# (34, 75, 234, 75, 'python')

# %%
a,b,c,d,e,g = p
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 a,b,c,d,e,g = p
#
# ValueError: not enough values to unpack (expected 6, got 5)

# %%
a
# Out:
# 34

# %%
b
# Out:
# 75

# %%
e
# Out:
# 'python'

# %%
tuple is faster than list


DS : 

numpy > tuple > list
